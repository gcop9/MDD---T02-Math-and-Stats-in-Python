# %%
## Practices ppt class 1-4
#ppt 1. Is the value 62.6738 rational or irrational? Why?
# Rational number, because it's a fractional number / has a decimal
x = 62.6738 
type(x)
# Out:
# float

# %%
#ppt 2. Evaluate the expression 10**7*10**-5
#Because we are multiplying the exponentations of both nummers this adds up
# 7+-5 = 2 

a = 10**7*10**-5
b = 10**2

print(a, b)
# Out:
# 100.00000000000001 100

# %%
#ppt 3. Evaluate the expression 81*1/2
# The exponentation by **1/2 is the same as the square root

from math import sqrt

a = 81**(1/2)
b = sqrt(81)

print(a, b)
# Out:
# 9.0 9.0

# %%
#ppt 4. Write a Python function named compute_logarithm that takes two parameters: ‘base’ and
#‘number’. The function should compute and return the logarithm of ‘number’ with base
#‘base’

def compute_logarithm(x):
    return log(a, b)

a = 8
b_values = [2, 4, 6]

for b in b_values:
    n = compute_logarithm(x)
    print(n)
# Out:
# 3.0
# 1.5
# 1.1605584217036247

# %%
## Essential Math for Data Science Chapter 1 Excersises 
# Book exercise 4. valuate the expression: 25**(3/2)

n = 25**(3/2)

#but n is also x 

x = (25**(1/2))**3

print('n =',n, 'and x =',x)
# Out:
# n = 125.0 and x = 125.0

# %%
# Book exercise 5. Assuming no payments are made, how much would a $1,000 loan be
    #worth at 5% interest compounded monthly after 3 years?

from math import exp

#Eulers number textbook example 
A1 = 100*(1+(.20/12))**(12*2)

#Excersise
p = 1000 #$ loan
r = .05 # interest 0,5% 
t = 3.0 #for 3 years
n = 12 #year has 12 months

A2 = p * (1 + (r/n))**(n * t)
print ('textbook example=',A1,'||',
       'excersise answer =','$',A2)
# Out:
# textbook example= 148.69146179463576 || excersise answer = $ 1161.4722313334678

# %%
# Book exercise 6. Assuming no payments are made, how much would a $1,000 loan be
    #worth at 5% interest compounded continuously after 3 years?
p = 1000
r = .05
t = 3.0 

a = p * exp(r*t)

print('$',a)
# Out:
# $ 1161.834242728283

# %%
# Book exercise 7.For the function f (x) = 3x + 1 what is the slope at x = 3?

from sympy import *
x = symbols('x')

#f(x)=3x**2+1
f = 3 * x ** 2 + 1
plot(f)

#Slope at x = 3 
dx_f = diff(f)
print(dx_f.subs(x,3))
# Out:
# 18

# %%
# Book excersise 8 For the function f (x) = 3x + 1 what is the area under the curve for
    #x between 0 and 2?

from sympy import *
x = symbols('x')

#f(x)=3x**2+1
f = 3 * x ** 2 + 1
plot(f)

#Slope between 0 and 2
a = integrate(f, (x, 0, 2))
print(a)
# Out:
# 10
