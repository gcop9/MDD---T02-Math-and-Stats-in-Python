# %%
## Practices ppt class 1-4
#ppt 1. Is the value 62.6738 rational or irrational? Why?
# Rational number, because it's a fractional number / has a decimal
x = 62.6738 
type(x)
# Out:
# float

# %%
#ppt 2. Evaluate the expression 10**7*10**-5
#Because we are multiplying the exponentations of both nummers this adds up
# 7+-5 = 2 

a = 10**7*10**-5
b = 10**2

print(a, b)
# Out:
# 100.00000000000001 100

# %%
#ppt 3. Evaluate the expression 81*1/2
# The exponentation by **1/2 is the same as the square root

from math import sqrt

a = 81**(1/2)
b = sqrt(81)

print(a, b)
# Out:
# 9.0 9.0

# %%
#ppt 4. Write a Python function named compute_logarithm that takes two parameters: ‘base’ and
#‘number’. The function should compute and return the logarithm of ‘number’ with base
#‘base’
